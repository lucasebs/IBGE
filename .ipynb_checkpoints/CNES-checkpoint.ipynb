# %%
import pandas as pd

# %%
arq_municipios = 'tbMunicipio201807'
df_municipios = pd.read_csv('CNES/BASE_DE_DADOS_CNES_201807/' + arq_municipios + '.csv', dtype={'user_id': int}  ,sep=';', low_memory=False)
df_municipios = df_municipios[df_municipios['CO_SIGLA_ESTADO'] == 'RN']
df_municipios = df_municipios[df_municipios['NO_MUNICIPIO'] == 'NATAL']
df_municipios
# Out:
#       CO_MUNICIPIO NO_MUNICIPIO CO_SIGLA_ESTADO TP_CADASTRO TP_PACTO  \
# 3615        240810        NATAL              RN           S        S
#
#       TP_ENVIA TP_ENVIA_CNES TP_CIB_SAS TP_PLENO_ORIGEM TP_MAC  NU_POPULACAO  \
# 3615         1             S          S               S      S           NaN
#
#       NU_DENSIDADE  CMTP_INICIO_MAC
# 3615           5.0          32018.0

# %%
estabelecimentos = 'tbEstabelecimento201807'
df_estabelecimentos = pd.read_csv('CNES/BASE_DE_DADOS_CNES_201807/' + estabelecimentos + '.csv', dtype={'user_id': int}  ,sep=';', low_memory=False)
df_estabelecimentos = df_estabelecimentos[df_estabelecimentos['CO_ESTADO_GESTOR'] == 24]
df_estabelecimentos = df_estabelecimentos[df_estabelecimentos['CO_MUNICIPIO_GESTOR'] == 240810]

df_estabelecimentos.head()
# Out:
#          CO_UNIDADE  CO_CNES  NU_CNPJ_MANTENEDORA  TP_PFPJ  NIVEL_DEP  \
# 1091  2408107772394  7772394                  NaN        1          1
# 1950  2408107656351  7656351                  NaN        3          1
# 2201  2408107656467  7656467                  NaN        3          1
# 2254  2408107658583  7658583                  NaN        3          1
# 2255  2408107663242  7663242                  NaN        3          1
#
#                                       NO_RAZAO_SOCIAL  \
# 1091                        OZENILDO TEODOZIO DE MELO
# 1950          ECOCARDIO NATAL ASSISTENCIA MEDICA LTDA
# 2201  NEURO VASCULAR CLINICA DE NEUROCIRURGIA LTDA ME
# 2254          LABORATORIO EMPRESARIAL DNA SS LTDA EPP
# 2255                              GRUPO REVIVER NATAL
#
#                               NO_FANTASIA             NO_LOGRADOURO  \
# 1091  CONSULTORIO MEDICO DR OZENILDO MELO        RUA JOAQUIM MANOEL
# 1950                      ECOCARDIO NATAL           RUA DIVINOPOLIS
# ...

# %%
df_estabelecimentos[df_estabelecimentos['TP_GESTAO'] == 'E']
# Out:
#            CO_UNIDADE  CO_CNES  NU_CNPJ_MANTENEDORA  TP_PFPJ  NIVEL_DEP  \
# 13269   2408105314267  5314267         8.241754e+12        3          3
# 20834   2408102823225  2823225         8.241754e+12        3          3
# 22459   2408104013581  4013581         8.241754e+12        3          3
# 24507   2408106532098  6532098         8.241754e+12        3          3
# 25043   2408107532970  7532970         8.241754e+12        3          3
# 85775   2408107305427  7305427         8.241754e+12        3          3
# 139876  2408105672465  5672465         8.241754e+12        3          3
# 177738  2408102693593  2693593         8.241754e+12        3          3
# 207791  2408107550626  7550626         8.241754e+12        3          3
# 260706  2408104013611  4013611         8.241754e+12        3          3
# 263816  2408106615902  6615902         8.241754e+12        3          3
#
#                                           NO_RAZAO_SOCIAL  \
# ...

# %%
regiao_leste = ['Cidade Alta', 'Petropolis', 'Tirol', 'Lagoa Seca', 'Alecrim',
                'Ribeira', 'Rocas', 'Barro Vermelho', 'Santos Reis', 'Praia do Meio',
                'Areia Preta', 'Mae Luiza']

regiao_oeste = ['Dix-Sept Rosado', 'Bom Pastor','Nossa Senhora de Nazare',
                'Cidade da Esperanca', 'Cidade Nova', 'Planalto', 'Felipe Camarao', 'Guarapes']

regiao_sul = ['Ponta Negra', 'Lagoa Nova', 'Capim Macio', 'Candelaria', 'Neopolis',
              'Nova Descoberta', 'Pitimbu', 'Planalto']

regiao_norte = ['Potengi', 'Redinha', 'Igapo','Pajucara', 'Nossa Senhora da Apresentacao',
                'Lagoa Azul', 'Salinas', 'Quintas', 'Nordeste']

# %%
df_aux = df_estabelecimentos[df_estabelecimentos['TP_UNIDADE'] == 2]

# %%
leste = 0
for bairro in regiao_leste:
    count = len(df_aux['NO_BAIRRO'] == bairro)    
    leste += count
leste
# Out:
# 876

# %%
oeste = 0
for bairro in regiao_oeste:
    count = len(df_aux['NO_BAIRRO'] == bairro)    
    oeste += count
oeste
# Out:
# 584

# %%
sul = 0 
for bairro in regiao_sul:
    count = len(df_aux['NO_BAIRRO'] == bairro)    
    sul += count
sul
# Out:
# 584

# %%
norte = 0 
for bairro in regiao_norte:
    count = len(df_aux['NO_BAIRRO'] == bairro)    
    norte += count
norte
# Out:
# 657
